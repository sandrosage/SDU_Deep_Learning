# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

full_four = np.full((2,3),4)
np_array = np.array([[1,2,3], [4,5,6]])
eye = np.eye(2,3)

#Addition of all the np-arrays: elementwise addition
d = full_four + np_array + eye

print(full_four)
print(np_array)
print(eye)
print(d)
# Out:
# [[4 4 4]
#  [4 4 4]]
# [[1 2 3]
#  [4 5 6]]
# [[1. 0. 0.]
#  [0. 1. 0.]]
# [[ 6.  6.  7.]
#  [ 8. 10. 10.]]

# %%
d4_np_array = np.array([[1,2,3,4,5],
    [5,4,3,2,1],
    [6,7,8,9,0],
    [0,9,8,7,6]])

print(d4_np_array)
print(np.sum(d4_np_array))

d4_np_array_t = np.transpose(d4_np_array)
print(d4_np_array_t)
# Out:
# [[1 2 3 4 5]
#  [5 4 3 2 1]
#  [6 7 8 9 0]
#  [0 9 8 7 6]]
# 90
# [[1 5 6 0]
#  [2 4 7 9]
#  [3 3 8 8]
#  [4 2 9 7]
#  [5 1 0 6]]

# %%
import pandas as pd 

df = pd.read_csv("Data/auto.csv")
df_mpg = df[df["mpg"] > 16]
df_mpg.head()
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0   18.0          8         307.0        130    3504          12.0
# 2   18.0          8         318.0        150    3436          11.0
# 4   17.0          8         302.0        140    3449          10.5
# 14  24.0          4         113.0         95    2372          15.0
# 15  22.0          6         198.0         95    2833          15.5
#
#     model_year  origin                       name
# 0           70       1  chevrolet chevelle malibu
# 2           70       1         plymouth satellite
# 4           70       1                ford torino
# 14          70       3      toyota corona mark ii
# 15          70       1            plymouth duster

# %%
df_weights_accel = df[["weight", "acceleration"]]
df_weights_accel.iloc[:6]
df.loc[:6, ["weight", "acceleration"]]
# Out:
#    weight  acceleration
# 0    3504          12.0
# 1    3693          11.5
# 2    3436          11.0
# 3    3433          12.0
# 4    3449          10.5
# 5    4341          10.0
# 6    4354           9.0

# %%
df_horsepower = df[df["horsepower"] != "?"]
df_horsepower = df_horsepower.astype({'horsepower':'int'})
"""
Convert single column to int dtype.
df['Fee'] = df['Fee'].astype('int')
"""
print(df_horsepower.dtypes)
df_horsepower.head()
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower        int32
# weight            int64
# acceleration    float64
# model_year        int64
# origin            int64
# name             object
# dtype: object
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0         130    3504          12.0
# 1  15.0          8         350.0         165    3693          11.5
# 2  18.0          8         318.0         150    3436          11.0
# 3  16.0          8         304.0         150    3433          12.0
# 4  17.0          8         302.0         140    3449          10.5
#
#    model_year  origin                       name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
print("AvG of mpg: " + str(df.mpg.mean()))
print("AvG of cylinders: " + str(df.cylinders.mean()))
print("AvG of displacement: " + str(df.displacement.mean()))
print("AvG of mpg: " + str(df.mpg.mean()))
print("AvG of weights: " + str(df.weight.mean()))
print("AvG of acceleration: " + str(df.acceleration.mean()))
print("AvG of model_year: " + str(df.model_year.mean()))
print("AvG of origin: " + str(df.origin.mean()))
# Out:
# AvG of mpg: 23.514572864321607
# AvG of cylinders: 5.454773869346734
# AvG of displacement: 193.42587939698493
# AvG of mpg: 23.514572864321607
# AvG of weights: 2970.424623115578
# AvG of acceleration: 15.568090452261307
# AvG of model_year: 76.01005025125629
# AvG of origin: 1.5728643216080402

# %%
a = np.array([1,1,2,3,5,8,13,21,34])
b = np.array([1,8,28,56,70,56,28,8,1])

import matplotlib.pyplot as plt

plt.plot(a, label="training accuracy")
plt.plot(b, label="validation accuracy")
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.title("Training and validation accuracy")
leg = plt.legend(loc='upper center')
plt.show()
